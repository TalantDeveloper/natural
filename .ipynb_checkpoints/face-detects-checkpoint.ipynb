# %%
# !pip install tensorflow opencv-python matplotlib

# %%
# Import standard deperdencies
import cv2
import numpy as np
import os
import random
from matplotlib import pyplot as plt

# %%
#Import tensoflow dependencies - Functional API
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\user\Desktop\natural\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Avoid OOM errors by setting GPU Memory Consumption
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
for gpu in gpus:
    print(gpu)

# %%
len(gpus)
# Out:
# 0

# %%
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.makedirs(POS_PATH)
#       2 os.makedirs(NEG_PATH)
#       3 os.makedirs(ANC_PATH)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data\\positive'

# %%
for directory in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw', directory)):
        EX_PATH = os.path.join('lfw', directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)
        os.replace(EX_PATH, NEW_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for directory in os.listdir('lfw'):
#       2     for file in os.listdir(os.path.join('lfw', directory)):
#       3         EX_PATH = os.path.join('lfw', directory, file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'lfw'

# %%
# Import uuid library to generate unique image names
import uuid
uuid.uuid1()
os.path.join(ANC_PATH, f"{uuid.uuid1()}.jpg")
# Out:
# 'data\\anchor\\ecc65739-c11d-11ee-bdbf-a81e8442ac4e.jpg'

# %%
# Establish a connection to the webcam
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    # Show image back to screen
    frame = frame[100:300, 250:450, :]

    # Collect anchors
    if cv2.waitKey(1) & 0xFF == ord('a'):
        # Create the unique file path
        imgname = os.path.join(ANC_PATH, f"{uuid.uuid1()}.jpg")
        # Write out anchor image
        cv2.imwrite(imgname, frame)
        
    # Collect positives
    if cv2.waitKey(1) & 0xFF == ord('p'):
        # Create out positive path
        imgname = os.path.join(POS_PATH, f"{uuid.uuid1()}.jpg")
        # Write out positive image
        cv2.imwrite(imgname, frame)
        
    # Show image back to screen
    cv2.imshow('Image Collection', frame)

    # Breaking gracefully
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

# %%
plt.imshow(frame)

# %%
frame.shape
# Out:
# (200, 200, 3)

# %%
# plt.imshow(frame[100:300, 250:450, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.imshow(frame[100:300, 250:450, :])
#
# File ~\Desktop\natural\venv\lib\site-packages\matplotlib\pyplot.py:3343, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3322 @_copy_docstring_and_deprecators(Axes.imshow)
#    3323 def imshow(
#    3324     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3341     **kwargs,
#    3342 ) -> AxesImage:
# -> 3343     __ret = gca().imshow(
#    3344         X,
#    3345         cmap=cmap,
#    3346         norm=norm,
#    3347         aspect=aspect,
#    3348         interpolation=interpolation,
#    3349         alpha=alpha,
#    3350         vmin=vmin,
#    3351         vmax=vmax,
#    3352         origin=origin,
#    3353         extent=extent,
#    3354         interpolation_stage=interpolation_stage,
#    3355         filternorm=filternorm,
#    3356         filterrad=filterrad,
#    3357         resample=resample,
#    3358         url=url,
#    3359         **({"data": data} if data is not None else {}),
#    3360         **kwargs,
#    3361     )
#    3362     sci(__ret)
#    3363     return __ret
#
# File ~\Desktop\natural\venv\lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File ~\Desktop\natural\venv\lib\site-packages\matplotlib\axes\_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5753 if aspect is not None:
#    5754     self.set_aspect(aspect)
# -> 5756 im.set_data(X)
#    5757 im.set_alpha(alpha)
#    5758 if im.get_clip_path() is None:
#    5759     # image does not already have clipping set, clip to axes patch
#
# File ~\Desktop\natural\venv\lib\site-packages\matplotlib\image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File ~\Desktop\natural\venv\lib\site-packages\matplotlib\image.py:700, in _ImageBase._normalize_image_array(A)
#     694 if A.ndim == 3:
#     695     # If the input data has values outside the valid range (after
#     696     # normalisation), we issue a warning and then clip X to the bounds
#     697     # - otherwise casting wraps extreme values, hiding outliers and
#     698     # making reliable interpretation impossible.
#     699     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
# --> 700     if A.min() < 0 or high < A.max():
#     701         _log.warning(
#     702             'Clipping input data to the valid range for imshow with '
#     703             'RGB data ([0..1] for floats or [0..255] for integers).'
#     704         )
#     705         A = np.clip(A, 0, high)
#
# File ~\Desktop\natural\venv\lib\site-packages\numpy\ma\core.py:5833, in MaskedArray.min(self, axis, out, fill_value, keepdims)
#    5831 # No explicit output
#    5832 if out is None:
# -> 5833     result = self.filled(fill_value).min(
#    5834         axis=axis, out=out, **kwargs).view(type(self))
#    5835     if result.ndim:
#    5836         # Set the mask
#    5837         result.__setmask__(newmask)
#
# File ~\Desktop\natural\venv\lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity
